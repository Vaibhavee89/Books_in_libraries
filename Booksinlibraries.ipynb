# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('book.csv')
df=pd.DataFrame(data)
k=pd.DataFrame(data)
l=pd.DataFrame(data)

# %%
df.head()
# Out:
#   Id                                               Name  RatingDist1  \
# 0  1  Harry Potter and the Half-Blood Prince (Harry ...  6.913888889
# 1  2  Harry Potter and the Order of the Phoenix (Har...      1:12455
# 2  3  Harry Potter and the Sorcerer's Stone (Harry P...     1:108202
# 3  4  Harry Potter and the Chamber of Secrets (Harry...      1:11896
# 4  5  Harry Potter and the Prisoner of Azkaban (Harr...      1:10128
#
#   pagesNumber RatingDist4 PublishYear Language       Authors Rating  \
# 0         652    4:556485        2006      eng  J.K. Rowling   4.57
# 1         870    4:604283        2004      eng  J.K. Rowling    4.5
# 2         309   4:1513191        2003      eng  J.K. Rowling   4.47
# 3         352    4:706082        2003      eng  J.K. Rowling   4.42
# 4         435    4:630534        2004      eng  J.K. Rowling   4.57
#
#   RatingDist2 RatingDist5 RatingDist3
# 0     2:25317   5:1546466    3:159960
# 1     2:37005   5:1493113    3:211781
# ...

# %%
lb=LabelEncoder()
for x in df:
  if type(x)!=type(32):
    df[x]=lb.fit_transform(df[x])

# %%
df=df.astype('int')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df=sc.fit_transform(df)

# %%
df=pd.DataFrame(df,columns=k.columns)

# %%
df=pd.DataFrame(df,columns=k.columns)
p=df.astype('int')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=0).fit(p)

# %%
#l.insert(0,'SHELF',0)

# %%
lastdf=pd.DataFrame(data)
lastdf.head()
# Out:
#    Shelf     Id   Name  RatingDist1  pagesNumber  RatingDist4  PublishYear  \
# 0      0      0  18896         2370         1955         7031          401
# 1      0   8131  18899         1633         2633         7111          399
# 2      0  14863  18904         1581         1163         5333          398
# 3      0  21657  18892         1619         1292         7258          398
# 4      0  28011  18902         1559         1496         7154          399
#
#    Language  Authors  Rating  RatingDist2  RatingDist5  RatingDist3
# 0       362    11252     385         2863         5617         4631
# 1       362    11252     378         2939         5552         4991
# 2       362    11252     375         2543         7074         5794
# 3       362    11252     370         3001         5564         5322
# 4       362    11252     385         2854         5844         4877

# %%
#lastdf=lastdf.drop('Shelf',axis=1)

# %%
#lastdf=lastdf.insert(0,'Shelf',0)

# %%
labe=kmeans.labels_

# %%
for x in range(len(lastdf)):
  lastdf['Shelf'][x]=labe[x]

# %%
#lastdf=lastdf.drop('SHELF',axis=1)

# %%
lastdf
# Out:
#        Shelf     Id   Name  RatingDist1  pagesNumber  RatingDist4  \
# 0          1      0  18896         2370         1955         7031
# 1          1   8131  18899         1633         2633         7111
# 2          1  14863  18904         1581         1163         5333
# 3          1  21657  18892         1619         1292         7258
# 4          1  28011  18902         1559         1496         7154
# ...      ...    ...    ...          ...          ...          ...
# 59879      2   1608  33806         2848         2378            0
# 59880      2   1609  41276         2798           81         3952
# 59881      2   1610  57368         3315         1410         3689
# 59882      2   1611  43777         3002          619         3786
# 59883      1   1612  57369         3314         2925         8153
#
#        PublishYear  Language  Authors  Rating  RatingDist2  RatingDist5  \
# 0              401       362    11252     385         2863         5617
# ...
